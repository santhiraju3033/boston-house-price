# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.datasets import load_boston

# %%
boston=load_boston()
boston.keys()
# Out:
# C:\Users\R SANTHIRAJU\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
# ...

# %%
print(boston.filename)
# Out:
# boston_house_prices.csv

# %%
dataset=pd.DataFrame(boston.data,columns=boston.feature_names)
dataset.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
dataset['price']=boston.target
dataset.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  price
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  price    506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %%
dataset.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
dataset.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# price      0
# dtype: int64

# %%
sns.boxplot(dataset['CRIM'])
# Out:
# C:\Users\R SANTHIRAJU\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='CRIM'>

# %%
sns.boxplot(dataset['ZN'])
# Out:
# C:\Users\R SANTHIRAJU\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ZN'>

# %%
iqr=dataset.CRIM.quantile(0.75)-dataset.CRIM.quantile(0.25)

# %%
lb=dataset.CRIM.quantile(0.25)-(1.5*iqr)
ub=dataset.CRIM.quantile(0.75)+(1.5*iqr)
print(lb,ub)
# Out:
# -5.31051125 9.06963875

# %%
dataset.loc[dataset['CRIM']>9,'CRIM']=9

# %%
iqr=dataset.ZN.quantile(0.75)-dataset.ZN.quantile(0.25)

# %%
lb=dataset.ZN.quantile(0.25)-(1.5*iqr)
ub=dataset.ZN.quantile(0.75)+(1.5*iqr)
print(lb,ub)
# Out:
# -18.75 31.25

# %%
dataset.loc[dataset['ZN']>31,'ZN']=31

# %%
sns.boxplot(dataset['ZN'])
# Out:
# C:\Users\R SANTHIRAJU\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ZN'>

# %%
dataset.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.370973  0.630097 -0.030171  0.664277 -0.264225  0.519389
# ZN      -0.370973  1.000000 -0.584143 -0.038160 -0.549567  0.331986 -0.582754
# INDUS    0.630097 -0.584143  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.030171 -0.038160  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.664277 -0.549567  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.264225  0.331986 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.519389 -0.582754  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.549471  0.679998 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.927674 -0.344125  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.871422 -0.384351  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.414503 -0.434116  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
sns.pairplot(dataset)

# %%
plt.scatter(dataset['CRIM'],dataset['price'])
plt.xlabel('crime rate')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
plt.scatter(dataset['RM'],dataset['price'])
plt.xlabel('RM')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
sns.regplot(x='RM',y='price',data=dataset)
# Out:
# <AxesSubplot:xlabel='RM', ylabel='price'>

# %%
sns.regplot(x='LSTAT',y='price',data=dataset)
# Out:
# <AxesSubplot:xlabel='LSTAT', ylabel='price'>

# %%
sns.regplot(x='CHAS',y='price',data=dataset)
# Out:
# <AxesSubplot:xlabel='CHAS', ylabel='price'>

# %%
sns.regplot(x='PTRATIO',y='price',data=dataset)
# Out:
# <AxesSubplot:xlabel='PTRATIO', ylabel='price'>

# %%
X=dataset.iloc[:,:-1]
y=dataset.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scalar=StandardScaler()

# %%
X_train=scalar.fit_transform(X_train)

# %%
X_test=scalar.transform(X_test)

# %%
import pickle
pickle.dump(scalar,open('scaling.pkl','wb'))

# %%
from sklearn.ensemble import RandomForestRegressor
regression=RandomForestRegressor(n_estimators=50,max_depth=3,max_leaf_nodes=10)
regression.fit(X_train,y_train)
# Out:
# RandomForestRegressor(max_depth=3, max_leaf_nodes=10, n_estimators=50)

# %%
reg_pred=regression.predict(X_test)
reg_pred
# Out:
# array([22.02072805, 29.83289959, 16.13150741, 24.26496889, 16.838411  ,
#        21.61466719, 17.65524451, 14.65565126, 21.53108148, 21.61466719,
#        18.15348676, 18.05588122, 11.71939618, 21.61466719, 21.61466719,
#        25.45834564, 16.90830295, 11.71939618, 43.18260952, 14.93793369,
#        24.26496889, 24.13076767, 15.76764476, 23.42627993, 15.7364275 ,
#        15.29617164, 22.02072805, 14.93814602, 18.15348676, 21.61466719,
#        19.23765335, 24.13076767, 25.32955584, 21.47802507, 15.47942879,
#        16.9098804 , 33.9965416 , 21.74144012, 19.23765335, 23.40884416,
#        16.24818209, 27.97799753, 43.18260952, 21.61466719, 22.24757129,
#        14.2127838 , 17.09112147, 24.19008064, 17.06493931, 26.40911615,
#        21.61466719, 31.12999367, 17.09112147, 25.82746491, 45.46575747,
#        21.53108148, 15.34303628, 31.89001537, 22.02072805, 17.97982009,
#        24.89067931, 32.36785792, 31.13771788, 21.53108148, 25.59891634,
# ...

# %%
plt.scatter(y_test,reg_pred)

# %%
residuals=y_test-reg_pred

# %%
sns.displot(residuals,kde=True)

# %%
plt.scatter(reg_pred,residuals)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(y_test,reg_pred))
print(mean_squared_error(y_test,reg_pred))
print(np.sqrt(mean_squared_error(y_test,reg_pred)))
# Out:
# 2.654274417403917
# 13.730120938342644
# 3.7054177818894654

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,reg_pred)
print(score)
# Out:
# 0.8185730502143971

# %%
1-(1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.8031576884679079

# %% [markdown]
# NEW DATA PREDICTION

# %%
scalar.transform(boston.data[0].reshape(1,-1))
# Out:
# C:\Users\R SANTHIRAJU\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-0.67382698,  0.86849171, -1.28656701, -0.28821362, -0.16592705,
#          0.34415812, -0.13400517,  0.15295316, -0.98016846, -0.68122373,
#         -1.32077101,  0.43481957, -1.04841834]])

# %%
regression.predict(scalar.transform(boston.data[0].reshape(1,-1)))
# Out:
# C:\Users\R SANTHIRAJU\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([26.40911615])

# %%
import pickle

# %%
pickle.dump(regression,open('regmodel.pkl','wb'))

# %%
pickled_model=pickle.load(open('regmodel.pkl','rb'))

# %%
pickled_model.predict(scalar.transform(boston.data[0].reshape(1,-1)))
# Out:
# C:\Users\R SANTHIRAJU\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([26.40911615])
